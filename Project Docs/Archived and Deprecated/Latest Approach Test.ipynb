# %% [markdown]
# # Re-Attempt at Local Fitting Scheme

# %%
import numpy as np
import utils
import evolutionTools as evt
import cv2
from scipy.optimize import minimize
import pandas as pd
import matplotlib.pyplot as plt
from copy import deepcopy
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def place_x_nodes(interval = (0, 575), n_nodes = evt.N + 2):
    start, end = interval
    N = n_nodes
    if N == 1:
        return [start]
    elif N == 2:
        return [start, end]
    
    step = (end - start) // (N - 1)
    
    # Generate nodes
    nodes = [start + i * step for i in range(N)]
    
    # Ensure the last element is exactly the end
    nodes[-1] = end
    
    return np.array(nodes)

# %%
def get_upper_waveform(video_name, image_number, OUTPUT = False):   #no path - just number
    image_path = "Data/video"+video_name+"_TREATED/"+"image"+ str(image_number) +".jpg"
    frame = cv2.imread(image_path)
    frame = utils.image_processing(frame) #To get two dimensional array instead of 3 (Grayscale)
    
    waveform = utils.get_waveform(frame) #Upper and Lower surfaces
    upper_surface = waveform[:, 0]

    #plt.plot(np.arange(utils.width), middle_line, label = "middle")     # CAN CHANGE
    #plt.show()
    
    return upper_surface

# %%
def interpolate(x, y, u):
    # Extrapolation for u less than x[0]
    if u < x[0]:
        x_i, x_ip1 = x[0], x[1]
        y_i, y_ip1 = y[0], y[1]
        v = y_i + ((u - x_i) * (y_ip1 - y_i)) / (x_ip1 - x_i)
        return v

    # Extrapolation for u greater than x[-1]
    if u > x[-1]:
        x_i, x_ip1 = x[-2], x[-1]
        y_i, y_ip1 = y[-2], y[-1]
        v = y_i + ((u - x_i) * (y_ip1 - y_i)) / (x_ip1 - x_i)
        return v

    # Interpolation for u within the bounds
    for i in range(len(x) - 1):
        if x[i] <= u <= x[i + 1]:
            x_i, x_ip1 = x[i], x[i + 1]
            y_i, y_ip1 = y[i], y[i + 1]
            v = y_i + ((u - x_i) * (y_ip1 - y_i)) / (x_ip1 - x_i)
            return v
    
    # If the code reaches here, it means something went wrong
    raise RuntimeError("Interpolation error")

# %%
def segment_energy(x_ext, y_ext, initial_length, stiffness, x_nodes, y_nodes):
    total_length = 0
    current_point = (x_ext[0], y_ext[0])
    end_point = (x_ext[1], y_ext[1])
    for i in range(x_nodes.shape[0]):
        if current_point[0] <= x_nodes[i] <= end_point[0]:
            total_length += evt.euclideanDistance(current_point, (x_nodes[i], y_nodes[i]))
            current_point = (x_nodes[i], y_nodes[i])
        if x_nodes[i] > end_point[0]:
            break
    total_length += evt.euclideanDistance(current_point, end_point)
    return 0.5 * stiffness * ((initial_length - total_length)**2)

# %%
def potential_energy(u_arr, x, y, lengths, k):
    u = np.zeros(x.shape[0])
    for j in range(u_arr.shape[0]):
        u[j+1] = u_arr[j] 
    new_x = x + u
    new_y = np.zeros(y.shape[0])
    for i in range(y.shape[0]):
        new_y[i] = interpolate(x, y, new_x[i])
    segment_energies = np.zeros(k.shape[0])
    for l in range(segment_energies.shape[0]):
        segment_energies[l] = segment_energy(new_x[l:l+2], new_y[l:l+2], lengths[l], k[l], x, y)
    energy = np.sum(segment_energies)
    return energy

# %%
def get_frame_potential(video_name, image_number, initial_lengths, K_arr, initial_guess, x_nodes):
    waveform = get_upper_waveform(video_name, image_number)
    y_nodes = waveform[x_nodes]
    disp = minimize(
        potential_energy,
        initial_guess,
        args = (x_nodes, y_nodes, initial_lengths, K_arr)
        )
    displacements = disp.x
    energy = potential_energy(displacements, x_nodes, y_nodes, initial_lengths, K_arr)
    return energy, displacements

# %%
def potential_evolution(video_name, total_images, increment = 1):
    image_number = 1
    x_nodes = place_x_nodes((0, 575), evt.N +  2)
    waveform = get_upper_waveform(video_name, image_number)
    y_nodes = waveform[x_nodes]
    initial_lengths = evt.initialLengthsFinder(x_nodes, y_nodes)
    #print(initial_lengths)
    #print(f'Initial lengths: {initial_lengths}')
    stiffnesses = np.ones(evt.N+1)/(initial_lengths)
    energy_array = np.zeros(total_images)
    initial_guess = np.zeros(evt.N)
    displacements = []
    while image_number <= total_images:
       print(f'Processing Frame: {image_number}  ')
       new_energy, displacement = get_frame_potential(video_name,
                                                       image_number,
                                                       initial_lengths,
                                                       stiffnesses,
                                                       initial_guess,
                                                       x_nodes)
       energy_array[image_number - 1] = new_energy
       print(f'Frame Energy = {new_energy}')
       displacements.append(deepcopy(displacement))
       initial_guess = displacement
       image_number += increment
    return energy_array, np.array(displacements)

# %%
energy, displacements = potential_evolution(video_name="007MA_Left_20160304_140907.avi", total_images=139, increment=1)
# Out:
# Processing Frame: 1
# Frame Energy = 0.0
# Processing Frame: 2
# Frame Energy = 0.0005813569696338973
# Processing Frame: 3
# Frame Energy = 0.0005149260944394613
# Processing Frame: 4
# Frame Energy = 0.0002666459418772841
# Processing Frame: 5
# Frame Energy = 0.00021565765946815428
# Processing Frame: 6
# Frame Energy = 0.0003175783923058037
# Processing Frame: 7
# Frame Energy = 0.0037521169820080563
# Processing Frame: 8
# Frame Energy = 0.001701820265081288
# Processing Frame: 9
# Frame Energy = 0.0013325507661183537
# Processing Frame: 10
# Frame Energy = 3.8355106955031245e-05
# Processing Frame: 11
# Frame Energy = 0.0017852758583557816
# Processing Frame: 12
# Frame Energy = 0.0010711724733593862
# Processing Frame: 13
# Frame Energy = 0.0010501784356256533
# Processing Frame: 14
# Frame Energy = 0.001650411869485861
# Processing Frame: 15
# Frame Energy = 0.0013991796388074919
# Processing Frame: 16
# Frame Energy = 0.0005592264255907463
# Processing Frame: 17
# Frame Energy = 0.00035142385987330484
# Processing Frame: 18
# Frame Energy = 0.0012161014721163157
# Processing Frame: 19
# Frame Energy = 0.00012622321748105962
# Processing Frame: 20
# Frame Energy = 0.0022017202714705243
# Processing Frame: 21
# Frame Energy = 0.0009360647458408006
# Processing Frame: 22
# Frame Energy = 0.0006680249511479511
# Processing Frame: 23
# Frame Energy = 0.0008191680005389748
# Processing Frame: 24
# Frame Energy = 8.231488787337168e-05
# Processing Frame: 25
# Frame Energy = 0.0012717345193409316
# Processing Frame: 26
# Frame Energy = 0.0013353481877706173
# Processing Frame: 27
# Frame Energy = 0.001553994079002277
# Processing Frame: 28
# Frame Energy = 0.0005417967304218697
# Processing Frame: 29
# Frame Energy = 0.003007491431546018
# Processing Frame: 30
# Frame Energy = 0.0010228259757681958
# Processing Frame: 31
# Frame Energy = 0.003493408712661107
# Processing Frame: 32
# Frame Energy = 0.007799789531869637
# Processing Frame: 33
# Frame Energy = 0.005296960831273659
# Processing Frame: 34
# Frame Energy = 0.008756686165556377
# Processing Frame: 35
# Frame Energy = 0.010577691233136661
# Processing Frame: 36
# Frame Energy = 0.012646773850710478
# Processing Frame: 37
# Frame Energy = 0.010898842874909647
# Processing Frame: 38
# Frame Energy = 0.023173493717838566
# Processing Frame: 39
# Frame Energy = 0.02178226618855216
# Processing Frame: 40
# Frame Energy = 0.020108258489888363
# Processing Frame: 41
# Frame Energy = 0.018895015679564975
# Processing Frame: 42
# Frame Energy = 0.021085130618021045
# Processing Frame: 43
# Frame Energy = 0.03462834214671076
# Processing Frame: 44
# Frame Energy = 0.027418450080651243
# Processing Frame: 45
# Frame Energy = 0.024674725825122593
# Processing Frame: 46
# Frame Energy = 0.02045666384776176
# Processing Frame: 47
# Frame Energy = 0.025277994069919263
# Processing Frame: 48
# Frame Energy = 0.03149488088984762
# Processing Frame: 49
# Frame Energy = 0.03033748808340178
# Processing Frame: 50
# Frame Energy = 0.02773182717231977
# Processing Frame: 51
# Frame Energy = 0.04662796389602426
# Processing Frame: 52
# Frame Energy = 0.035127127257380375
# Processing Frame: 53
# Frame Energy = 0.03567012630409068
# Processing Frame: 54
# Frame Energy = 0.036774317559735294
# Processing Frame: 55
# Frame Energy = 0.05638732909651427
# Processing Frame: 56
# Frame Energy = 0.05558242374286537
# Processing Frame: 57
# Frame Energy = 0.050364807682739314
# Processing Frame: 58
# Frame Energy = 0.07135721303078231
# Processing Frame: 59
# Frame Energy = 0.08108137230200484
# Processing Frame: 60
# Frame Energy = 0.0711880156257232
# Processing Frame: 61
# Frame Energy = 0.07506594060922193
# Processing Frame: 62
# Frame Energy = 0.06667736384362002
# Processing Frame: 63
# Frame Energy = 0.06112440206772846
# Processing Frame: 64
# Frame Energy = 0.08341537809422268
# Processing Frame: 65
# Frame Energy = 0.09653437937382944
# Processing Frame: 66
# Frame Energy = 0.07825549061839615
# Processing Frame: 67
# Frame Energy = 0.07603068662739931
# Processing Frame: 68
# Frame Energy = 0.07909076724474405
# Processing Frame: 69
# Frame Energy = 0.07679887033380386
# Processing Frame: 70
# Frame Energy = 0.07143418480995278
# Processing Frame: 71
# Frame Energy = 0.06868175033236516
# Processing Frame: 72
# Frame Energy = 0.05608407894787091
# Processing Frame: 73
# Frame Energy = 0.05549258664511432
# Processing Frame: 74
# Frame Energy = 0.07492210710960687
# Processing Frame: 75
# Frame Energy = 0.06992980674048113
# Processing Frame: 76
# Frame Energy = 0.07186725829542262
# Processing Frame: 77
# Frame Energy = 0.06701556055141034
# Processing Frame: 78
# Frame Energy = 0.0671973036086896
# Processing Frame: 79
# Frame Energy = 0.06992693466920795
# Processing Frame: 80
# Frame Energy = 0.059173012419988555
# Processing Frame: 81
# Frame Energy = 0.059905995226407535
# Processing Frame: 82
# Frame Energy = 0.053338245020751206
# Processing Frame: 83
# Frame Energy = 0.046553483798395884
# Processing Frame: 84
# Frame Energy = 0.0525211192626897
# Processing Frame: 85
# Frame Energy = 0.04614191526838132
# Processing Frame: 86
# Frame Energy = 0.03921223490761819
# Processing Frame: 87
# Frame Energy = 0.051688133249827566
# Processing Frame: 88
# Frame Energy = 0.04295089349264246
# Processing Frame: 89
# Frame Energy = 0.04077748022761152
# Processing Frame: 90
# Frame Energy = 0.03696307937614248
# Processing Frame: 91
# Frame Energy = 0.024963503167282134
# Processing Frame: 92
# Frame Energy = 0.02020746145993411
# Processing Frame: 93
# Frame Energy = 0.01393605227586254
# Processing Frame: 94
# Frame Energy = 0.006393998166032945
# Processing Frame: 95
# Frame Energy = 0.0064832495759557405
# Processing Frame: 96
# Frame Energy = 0.006515688432475677
# Processing Frame: 97
# Frame Energy = 0.004047170708505056
# Processing Frame: 98
# Frame Energy = 0.00476179650310037
# Processing Frame: 99
# Frame Energy = 0.00421176717404648
# Processing Frame: 100
# Frame Energy = 0.004880510918657126
# Processing Frame: 101
# Frame Energy = 0.004735523036157624
# Processing Frame: 102
# Frame Energy = 0.0029953207043717438
# Processing Frame: 103
# Frame Energy = 11.841982438619837
# Processing Frame: 104
# Frame Energy = 0.005059336909680469
# Processing Frame: 105
# Frame Energy = 0.005545525656064539
# Processing Frame: 106
# Frame Energy = 0.003368528076700918
# Processing Frame: 107
# Frame Energy = 0.00394225746295545
# Processing Frame: 108
# Frame Energy = 0.004132233619423544
# Processing Frame: 109
# Frame Energy = 0.0032202343117251294
# Processing Frame: 110
# Frame Energy = 0.00671231600978403
# Processing Frame: 111
# Frame Energy = 0.003206840140916701
# Processing Frame: 112
# Frame Energy = 0.00035763170027752414
# Processing Frame: 113
# Frame Energy = 0.004243926520966733
# Processing Frame: 114
# Frame Energy = 0.005295121644334776
# Processing Frame: 115
# Frame Energy = 0.002229515701294923
# Processing Frame: 116
# Frame Energy = 0.005582429304460296
# Processing Frame: 117
# Frame Energy = 0.006555693834411062
# Processing Frame: 118
# Frame Energy = 0.004295845389908637
# Processing Frame: 119
# Frame Energy = 0.006329124475436698
# Processing Frame: 120
# Frame Energy = 0.0035460929018348605
# Processing Frame: 121
# Frame Energy = 0.006681105453275128
# Processing Frame: 122
# Frame Energy = 0.0027573949555815187
# Processing Frame: 123
# Frame Energy = 0.0010991719233579232
# Processing Frame: 124
# Frame Energy = 0.0027609596559823456
# Processing Frame: 125
# Frame Energy = 0.0010967663136344458
# Processing Frame: 126
# Frame Energy = 0.0015851974460100084
# Processing Frame: 127
# Frame Energy = 0.0027584844250682574
# Processing Frame: 128
# Frame Energy = 0.0011492344176950602
# Processing Frame: 129
# Frame Energy = 0.0039142046875234
# Processing Frame: 130
# Frame Energy = 0.00286232825475319
# Processing Frame: 131
# Frame Energy = 0.0049745755342044395
# Processing Frame: 132
# Frame Energy = 0.0031788492558821415
# Processing Frame: 133
# Frame Energy = 0.002202665131030275
# Processing Frame: 134
# Frame Energy = 0.00400954135851591
# Processing Frame: 135
# Frame Energy = 0.0009392262146089019
# Processing Frame: 136
# Frame Energy = 0.0055824695280329815
# Processing Frame: 137
# Frame Energy = 0.0023089061230086735
# Processing Frame: 138
# Frame Energy = 0.002233908488219115
# Processing Frame: 139
# Frame Energy = 0.0023882298704395372

# %%
np.argmax(energy)
# Out:
# 102

# %%
filtered_energy = np.array([i for i in energy if i != energy[102]])

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.linspace(0,1, filtered_energy.shape[0]), filtered_energy, marker='o', linestyle='-', color='b')
plt.xlabel('Time Progression')
plt.ylabel('Energy')
plt.title('Energy vs Frame')
plt.grid(True)
plt.show()
